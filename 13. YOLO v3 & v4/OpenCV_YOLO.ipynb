# %% [markdown]
# <a href="https://colab.research.google.com/github/KillerStrike17/EVA-5/blob/master/13.%20YOLO%20v3%20%26%20v4/OpenCV_YOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#loading the gods 
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
# Mounting drive to get the config and weights
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Loading the dataset, config file and inferenece image
# !cp "/content/gdrive/My Drive/Open CV YOLO/yolo_object_detection.zip" "/content/"
# !cp "/content/gdrive/My Drive/Open CV YOLO/yolov3.weights" "/content/"
# !cp "/content/gdrive/My Drive/Open CV YOLO/My_image.PNG" "/content/"

# %%
# !unzip yolo_object_detection.zip
# Out:
# Archive:  yolo_object_detection.zip
#   inflating: room_ser.jpg
#   inflating: yolo_object_detection.py
#   inflating: coco.names
#   inflating: yolov3.cfg

# %%
# Load Yolo
net = cv2.dnn.readNet("yolov3.weights", "yolov3.cfg")
classes = []
with open("coco.names", "r") as f:
    classes = [line.strip() for line in f.readlines()]
layer_names = net.getLayerNames()
output_layers = [layer_names[i[0] - 1] for i in net.getUnconnectedOutLayers()]
colors = np.random.uniform(0, 255, size=(len(classes), 3))

# %%
# Loading image
img = cv2.imread("My_image.PNG")
img = cv2.resize(img, None, fx=0.4, fy=0.4)
height, width, channels = img.shape

# %%
# Detecting objects
blob = cv2.dnn.blobFromImage(img, 0.00392, (416, 416), (0, 0, 0), True, crop=False)
net.setInput(blob)
outs = net.forward(output_layers)

# %%
# Showing informations on the screen
class_ids = []
confidences = []
boxes = []
for out in outs:
    for detection in out:
        scores = detection[5:]
        class_id = np.argmax(scores)
        confidence = scores[class_id]
        if confidence > 0.5:
            # Object detected
            center_x = int(detection[0] * width)
            center_y = int(detection[1] * height)
            w = int(detection[2] * width)
            h = int(detection[3] * height)

            # Rectangle coordinates
            x = int(center_x - w / 2)
            y = int(center_y - h / 2)

            boxes.append([x, y, w, h])
            confidences.append(float(confidence))
            class_ids.append(class_id)

# %%
indexes = cv2.dnn.NMSBoxes(boxes, confidences, 0.5, 0.4)
print(indexes)
font = cv2.FONT_HERSHEY_PLAIN
for i in range(len(boxes)):
    if i in indexes:
        x, y, w, h = boxes[i]
        label = str(classes[class_ids[i]])
        color = colors[class_ids[i]]
        cv2.rectangle(img, (x, y), (x + w, y + h), color, 2)
        cv2.putText(img, label, (x, y + 30), font, 3, color, 3)


cv2_imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# [[0]]
# <PIL.Image.Image image mode=RGB size=243x242 at 0x7F40C9F20320>
